// %% [markdown]
// # Übungsblatt 02 – Variablen, Typen und Ausdrücke
//
// **Woche 2 · 10 Aufgaben: 8 × Java, 2 × Turtle**
//
// Bearbeiten Sie die Aufgaben der Reihe nach. Die späteren Aufgaben verbinden mehrere Ideen. Schreiben Sie Antworten auf Verständnisfragen als Kommentar (`// ...`) in die Codezelle oder als Markdown unter die Aufgabe. Für Aufgaben 9 und 10 zuerst die beiden Turtle-Setup-Zellen ausführen.

// %% [markdown]
// ## Aufgabe 1 – Deklarieren und zuweisen (Java)
//
// Deklarieren Sie in `main` eine ganze Zahl `personen`, eine Kommazahl `preisProPerson` und einen Text `anlass` zunächst **ohne Wert**. Weisen Sie ihnen danach `8`, `4.50` und `"Spieleabend"` zu. Geben Sie alle drei Werte aus. Ändern Sie anschliessend `personen` auf `10` und führen Sie die Zelle erneut aus. Was hat sich geändert?

// %%
class Aufgabe01 {
    public static void main(String[] args) {
        // TODO: Variablen deklarieren, Werte zuweisen und ausgeben.
    }
}
Aufgabe01.main(new String[0]);

// %% [markdown]
// ## Aufgabe 2 – Wozu dienen Typen? (Java)
//
// Für einen Kinobesuch sollen `film = "Sternenreise"`, `plaetze = 24` und `dauerStunden = 1.75` gespeichert werden. Wählen Sie jeweils zwischen `String`, `int` und `double` und schreiben Sie die Deklarationen mit Zuweisung. Begründen Sie in Kommentaren, warum `int dauerStunden = 1.75;` nicht passt und wie Typen Fehler sichtbar machen. Geben Sie einen Satz mit allen drei Variablen aus.

// %%
class Aufgabe02 {
    public static void main(String[] args) {
        // TODO: Drei passend typisierte Variablen und eine Ausgabe.
        // Warum hilft ein Typ dabei, Fehler zu entdecken?
    }
}
Aufgabe02.main(new String[0]);

// %% [markdown]
// ## Aufgabe 3 – Ausdruck oder Anweisung? (Java)
//
// Markieren Sie in Kommentaren je **eine vollständige Anweisung** und **zwei Ausdrücke**, die im gegebenen Programm vorkommen. Welchen Wert hat `punkte`, wenn die Ausgabe erreicht wird? Ergänzen Sie eine zweite Ausgabe für `punkte * 2`. Erklären Sie, ob `punkte * 2` allein eine vollständige Anweisung ist.

// %%
class Aufgabe03 {
    public static void main(String[] args) {
        int punkte = 4;
        punkte = punkte + 3;
        System.out.println("Punkte: " + punkte);
        // TODO: Kommentare und zweite Ausgabe.
    }
}
Aufgabe03.main(new String[0]);

// %% [markdown]
// ## Aufgabe 4 – Rechnen mit int und double (Java)
//
// `17` Sticker werden auf `5` Personen verteilt. Berechnen und drucken Sie (a) die Anzahl ganzer Sticker pro Person mit `/`, (b) den Rest mit `%` und (c) den rechnerischen Durchschnitt als `double`. Dividieren Sie für (c) durch `5.0`. Sagen Sie vor dem Ausführen voraus, warum (a) und (c) verschieden sind.

// %%
class Aufgabe04 {
    public static void main(String[] args) {
        int sticker = 17;
        int personen = 5;
        // TODO: Ganzzahlige Division, Rest und Durchschnitt berechnen.
    }
}
Aufgabe04.main(new String[0]);

// %% [markdown]
// ## Aufgabe 5 – Der Operator + bei Zahlen und Text (Java)
//
// Mit `jahr = 2` und `zusatz = 3`: Sagen Sie das Ergebnis von `"Jahr " + jahr + zusatz` voraus und geben Sie den Ausdruck aus. Erzeugen Sie danach mit Klammern die Ausgabe `Jahr 5`. Bilden Sie zusätzlich aus `vorname` und `nachname` einen Namen mit Leerzeichen. Erklären Sie kurz, wann `+` addiert und wann es Texte verbindet.

// %%
class Aufgabe05 {
    public static void main(String[] args) {
        int jahr = 2;
        int zusatz = 3;
        String vorname = "Mira";
        String nachname = "Keller";
        // TODO: Drei Ausgaben und eine kurze Erklärung als Kommentar.
    }
}
Aufgabe05.main(new String[0]);

// %% [markdown]
// ## Aufgabe 6 – Rechenreihenfolge und Zwischenwerte (Java)
//
// Eine Gruppe kauft `3` Hefte zu je `4.50` Franken und `2` Stifte zu je `1.20` Franken. Auf die Gesamtsumme gibt es `10 %` Rabatt. Speichern Sie Mengen als `int`, Preise und Rabatt als `double`. Berechnen Sie die Summe vor Rabatt, den Rabattbetrag und den Endpreis als benannte Zwischenwerte. Geben Sie jeden Wert mit einem erklärenden Text aus. Prüfen Sie mit einer Handrechnung, ob der Rabatt auf **beide** Produkte angewandt wurde.

// %%
class Aufgabe06 {
    public static void main(String[] args) {
        int anzahlHefte = 3;
        int anzahlStifte = 2;
        double preisHeft = 4.50;
        double preisStift = 1.20;
        double rabatt = 0.10;
        // TODO: Summe, Rabattbetrag und Endpreis berechnen und ausgeben.
    }
}
Aufgabe06.main(new String[0]);

// %% [markdown]
// ## Aufgabe 7 – Drei Arten von Fehlern (Java)
//
// Ordnen Sie den drei Fällen **Übersetzungsfehler**, **Laufzeitfehler** oder **logischen Fehler** zu. Begründen Sie jeweils, ob das Programm startet und was beim Ausführen passiert. Reparieren Sie dann alle drei Fälle in der Codezelle, ohne den beabsichtigten Wert zu ändern.
//
// ```java
// String ort = 42;                    // A: Der Ortsname soll "Basel" sein.
// int gruppen = 0;
// int personenJeGruppe = 12 / gruppen; // B: Es sollen 3 Gruppen sein.
// int minuten = 95;
// double stunden = minuten / 60;       // C: 95 Minuten in Stunden.
// ```

// %%
class Aufgabe07 {
    public static void main(String[] args) {
        // TODO: Alle drei reparierten Fälle mit Resultaten ausgeben.
        // Fall A: ...  Fall B: ...  Fall C: ...
    }
}
Aufgabe07.main(new String[0]);

// %% [markdown]
// ## Aufgabe 8 – Ein kleines Programm planen (Java)
//
// Für einen Ausflug stehen `30.0` Franken bereit. `7` Teilnehmende brauchen je ein Ticket zu `3.75` Franken. Schreiben Sie ein Programm mit sinnvoll benannten Variablen. Berechnen Sie Gesamtkosten und verbleibendes Geld. Geben Sie einen verständlichen Satz mit Anlass, Anzahl, Gesamtkosten und Rest aus. Notieren Sie in Kommentaren, welche Zeilen Deklarationen, Zuweisungen und Ausdrücke enthalten. Ändern Sie die Anzahl auf `8`: Was zeigt der Rest dann an, und warum? Benutzen Sie noch keine Bedingungen.

// %%
class Aufgabe08 {
    public static void main(String[] args) {
        // TODO: Eigenes Programm für den Ausflug.
    }
}
Aufgabe08.main(new String[0]);

// %% [markdown]
// ## Turtle vorbereiten
//
// Führen Sie die nächsten beiden Zellen **in dieser Reihenfolge** aus. Die `%maven`-Zeilen sind Jupyter-Befehle und kein gewöhnlicher Java-Code. Nach einem Kernel-Neustart müssen Sie sie erneut ausführen. Die Bibliothek entspricht der Vorlesungsvorlage `02_turtle.ipynb`.

// %%
%mavenRepo shapemodelling-repo https://shapemodelling.cs.unibas.ch/repo/
%maven ch.unibas.informatik:jturtle:0.7

// %%
import static ch.unibas.informatik.jturtle.TurtleCommands.*;

// %% [markdown]
// ## Aufgabe 9 – Rechteck mit Variablen (Turtle)
//
// Zeichnen Sie von der Mitte aus ein Rechteck mit `breite = 60` und `hoehe = 35`. Verwenden Sie für die vier Strecken nur diese Variablen, keine hineinkopierten Zahlen. Benutzen Sie `forward`, `turnRight` und `display(drawing())`; Schleifen sind noch nicht nötig. Berechnen Sie ausserdem den Umfang in Java und geben Sie ihn als Text aus. Wo steht die Turtle am Ende, wenn das Rechteck geschlossen ist?

// %%
class Aufgabe09 {
    public static void main(String[] args) {
        int breite = 60;
        int hoehe = 35;
        clear();
        reset();
        home();
        penDown();
        // TODO: Rechteck zeichnen und Umfang ausgeben.
        display(drawing());
    }
}
Aufgabe09.main(new String[0]);

// %% [markdown]
// ## Aufgabe 10 – Zwei Werte als Balken darstellen (Turtle)
//
// Stellen Sie `wertA = 18.0` und `wertB = 32.0` als **zwei senkrechte Balken** dar. Mit `faktor = 2.0` soll die Länge jedes Balkens `wert * faktor` sein. Starten Sie beide Balken auf gleicher Höhe, aber mit 30 Schritten Abstand. Zeichnen Sie A blau und B rot (`penColor(BLUE)`/`penColor(RED)`), jeweils mit `penSize(5)`. Zwischen den Balken den Stift mit `penUp()` anheben. Geben Sie zusätzlich einen Satz mit der Differenz `wertB - wertA` aus. Überlegen Sie vor dem Zeichnen, warum beide Balken im 200 × 200 grossen Zeichenbereich sichtbar bleiben. Benutzen Sie nur Variablen, Ausdrücke und die bekannten Turtle-Befehle, keine Schleifen.

// %%
class Aufgabe10 {
    public static void main(String[] args) {
        double wertA = 18.0;
        double wertB = 32.0;
        double faktor = 2.0;
        clear();
        reset();
        home();
        // TODO: Zwei Balken zeichnen, Differenz berechnen und ausgeben.
        display(drawing());
    }
}
Aufgabe10.main(new String[0]);
